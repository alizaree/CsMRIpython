# %%
## importing modules and loading the data
import numpy as np
import os
import nibabel as nib
import matplotlib as mlp
import MainFunctions as MF
import bokeh
import bokeh.plotting as bpl
from bokeh.models import ColorBar, BasicTicker, LinearColorMapper
import wav as wav
import matplotlib.pyplot as plt
# downloading the data
path0=os.getcwd()

# %%
# download the data if it doesnt exist. 
path=path0+'/content/bold5000/sub-CSI3_anat/sub-CSI3_ses-16_T1w.nii.gz'
downloaded=os.path.isfile(path)
if not downloaded:
    # !pip install awscli
    os.chdir(path0)
    os.mkdir('./content')
    os.chdir('./content')
    os.mkdir('./bold5000')
    os.chdir(path0+'/content/bold5000')
    # !aws s3 sync --no-sign-request s3://openneuro.org/ds001499/sub-CSI3/ses-16/anat/ ./sub-CSI3_anat/
    os.chdir(path0)
# load the data
data,hdr= MF.load_data()

# %%
# looking at a sample slice of the data
Nx = data.shape[0]
Ny = data.shape[1]
Nz = data.shape[2]
n = Ny
X = data[Nx//2, :, :];
bpl.output_notebook()
MF.imagesc(data[Nx//2, :, :], title='MR Image We Will Recover')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="06e3bf4c-4484-4d78-8d17-b440f7b957e6" data-root-id="1002"></div>
# Figure(id='1002', ...)

# %%
# create a remove map for random sampling:
import undersampling as us
prob=0.5
idxs=us.rmvMap_brn(prob, n,n)
print(idxs.shape)
print(n**2)

# getting the undersampled pictures:
levels=2
wave=wav.gen_wavelet()
S, dummy=wav.DWT(X, wave, levels)# the wavelet of signal
sz=S.shape[0]
dummy, coeff_slices=wav.DWT(np.zeros((sz, sz)), wave, levels)
check=wav.iDWT(S, wave,levels, coeff_slices)
Y = np.abs(MF.measure_map(S, idxs, wave,levels, coeff_slices)) # takes idwt and does fft and undersamples. so Y is the undersampled pictures
# out of which we should reconstruct the original picture X.
print(np.sum(np.abs(check)-X))
# Out:
# (32803, 2)
# 65536
# 8.500782326748987e-10

# %%
# Getting the shape of our desired matrix
[p, q] = Y.shape
Y_frob = np.linalg.norm(Y, ord='fro')
Y_scaled = Y / Y_frob
sigma = np.std(Y_scaled)
S = np.random.normal(0, sigma, [p, q])
er=[]
# Creating an initial guess for S

# Initializing the regularizer
lambd = 1e-3
eps = 1e-4
itr= 5000
loss_value, S= MF.loss_prox2(S, Y, lambd,eps,Y_frob,idxs,levels,coeff_slices,wave,itr)
X_new = np.abs(Y_frob*wav.iDWT(S, wave,levels, coeff_slices))

er.append(np.linalg.norm(X_new - X, ord='fro'))

bpl.output_notebook()
MF.imagesc(np.abs(X_new), title = 'P = '+str(prob))
plt.plot(loss_value)
print(np.sum(np.abs(S)))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1110">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="af7ae7ef-7e0b-46f5-9134-1720785fd124" data-root-id="1111"></div>
# 47.929301822101834

# %%
MF.imagesc(np.abs(X_new), title = 'P = '+str(prob))
# Out:
#   <div class="bk-root" id="c6549688-09b2-4990-a395-857470ed82ea" data-root-id="1225"></div>
# Figure(id='1225', ...)

# %%
a=np.random.rand(256,256)

# %%
mine= MF.loss_prox2(a, Y, lambd,eps,Y_frob,idxs,levels,2 )
his=MF.loss_prox(a, Y, lambd,eps, idxs, wave, levels, coeff_slices, 2)
print(his)
print(mine)
# Out:
# ([14348029198900.043, 30.849113296818263, 30.786839493727143, 30.724574201614764], array([[-0.07311198-0.11548252j,  0.29742622-0.005667j  ,
#         -0.17662696-0.21526454j, ...,  0.62179669+0.20212163j,
#          0.74129964-0.22691042j,  0.65115502+0.061888j  ],
#        [ 0.29649054+0.14849597j,  0.04396525+0.0294126j ,
#          0.34620579-0.15815953j, ...,  0.6537631 -0.10997449j,
#          0.72526456+0.17102982j,  0.45080437-0.10427481j],
#        [-0.13304885-0.02163199j,  0.0771845 +0.02290715j,
#          0.01591357+0.11129004j, ...,  0.73041481+0.17024312j,
#          0.58705052-0.06288928j,  0.57538393+0.16247832j],
#        ...,
#        [ 0.44093617+0.08204586j,  0.808785  +0.08632149j,
#          0.37312499+0.37625362j, ...,  0.20849115+0.11575266j,
#          0.27325191-0.09808494j,  0.28189   -0.06701551j],
#        [ 0.54343283-0.18103264j,  0.40905925+0.04061587j,
#          0.81494767-0.0727759j , ...,  0.8043331 -0.09979069j,
#          0.38840284-0.08537527j,  0.40610705+0.08780426j],
#        [ 0.75154964+0.12225342j,  0.44465747+0.12387418j,
#          0.30342526+0.38980991j, ...,  0.70708877+0.07694136j,
#          0.62781182+0.10377937j,  0.67950937+0.0127932j ]]))
# ([14348029198900.043, 1928.5702404281278, 1928.5459056842847, 1928.5215719602472], array([[ 1.27598058e+07 +629504.52241115j,
#          1.08423040e+07 -959780.15360022j,
#          1.41736595e+07-1140184.15429675j, ...,
#         -1.25443992e+06 -134324.34243381j,
#          2.19930406e+06 -130250.22970346j,
#         -2.10172367e+06 +174013.9718747j ],
#        [ 1.18625731e+07+2184865.79401535j,
#          9.99230765e+07 +933216.22905596j,
#          7.37016334e+07-1136847.88119843j, ...,
#         -2.87518921e+06  -90460.42720906j,
#          4.72921406e+06 -200406.0361987j ,
#         -2.19218716e+07 +335508.46938341j],
#        [ 2.34266035e+07+2075814.3864667j ,
#          7.19162367e+07 +477999.13337433j,
#          5.14032709e+07 -353364.64461749j, ...,
#         -1.51401840e+06  -22865.3205724j ,
#          2.69120298e+06  -38531.40405779j,
#         -3.40018972e+06 +176393.33653184j],
#        ...,
#        [-2.28366426e+05 +109164.10256231j,
#          5.72216412e+05  -22865.81117808j,
#          3.60248306e+05 +150729.89903331j, ...,
#         -1.70457520e+04 -187890.69593051j,
#          7.11627438e+04 +167971.27692443j,
#         -4.25735808e+05 -127387.07181623j],
#        [-3.31842659e+05  +41200.30233214j,
#         -5.65019693e+05 -226566.34684693j,
#          2.73432546e+06 -254886.20424234j, ...,
#         -2.59149781e+05  +81774.81705963j,
#          1.05862063e+06 -174736.18418978j,
#          2.20588505e+06  -29038.18340876j],
#        [-1.03075234e+06  +44571.8332288j ,
#         -2.71197384e+07 +196925.68812033j,
#         -3.25447937e+06  -32128.0479554j , ...,
#          6.27776867e+05  -24707.38897139j,
#          2.93094537e+05 +166116.50103822j,
#          1.10601223e+07  +27688.14235064j]]))
